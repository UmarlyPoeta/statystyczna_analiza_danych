# %% [markdown]
# **Zanim zaczniesz pracę zapisz kopię na dysku**
#
#
#
#
# W tym zadaniu poćwiczymy pracę z **ramkami danych** w bibliotece **Pandas** na przykładzie zbioru `titanic.csv`.
#
# **Plik titanic** zawiera informacje dotyczące pasażerów statku RMS Titanic, który zatonął w kwietniu 1912 roku po zderzeniu z górą lodową. Plik ten jest często używany jako zestaw danych do nauki analizy danych, modelowania przewidywań i eksploracji danych.
#
# Typowy zestaw danych titanic zawiera nastepujące kolumny:
#
# - PassengerId: Unikalny identyfikator pasażera.
# - Survived: Informacja o tym, czy pasażer przeżył katastrofę (1 - przeżył, 0 - nie przeżył).
# - Pclass: Klasa biletu pasażera (1 - pierwsza klasa, 2 - druga klasa, 3 - trzecia klasa).
# - Name: Imię i nazwisko pasażera.
# - Sex: Płeć pasażera.
# - Age: Wiek pasażera.
# - SibSp: Liczba rodzeństwa / małżonków na pokładzie.
# - Parch: Liczba rodziców / dzieci na pokładzie.
# - Ticket: Numer biletu.
# - Fare: Cena biletu.
# - Cabin: Numer kabiny pasażera.
# - Embarked: Port, w którym pasażer wszedł na pokład statku (C - Cherbourg, Q - Queenstown, S - Southampton).

# %% [markdown]
# ## Zaimportuj biblioteki: NumPy i Pandas

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Pobierz zbiór danych ML-datasets z GitHub (Link: `https://github.com/matzim95/ML-datasets`)

# %%
# !wget https://github.com/matzim95/ML-datasets/titanic.csv
# Out:
# 7[Files: 0  Bytes: 0  [0 B/s] Re]8
# 7[https://github.com/matzim95/ML]87[Files: 0  Bytes: 0  [0 B/s] Re]87titanic.csv          100% [=============================>]       9     --.-KB/s87HTTP ERROR response 404  [https://github.com/matzim95/ML-datasets/titanic.csv]
# 87titanic.csv          100% [=============================>]       9     --.-KB/s87[Files: 0  Bytes: 9  [8 B/s] Re]8

# %%
# Out:
# Cloning into 'ML-datasets'...
# remote: Enumerating objects: 201, done.
# remote: Counting objects: 100% (141/141), done.
# remote: Compressing objects: 100% (117/117), done.
# remote: Total 201 (delta 35), reused 124 (delta 24), pack-reused 60 (from 1)
# Receiving objects: 100% (201/201), 35.87 MiB | 9.84 MiB/s, done.
# Resolving deltas: 100% (47/47), done.
# Updating files: 100% (130/130), done.

# %% [markdown]
# ## Załaduj plik titanic.csv z pobranego folderu i zapisz go jako zmienną titanic.
# ## Wyswietl 10 pierwszych wierszy

# %%
df = pd.read_csv('titanic.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ## wyświtl rozmiar/kształt zbioru

# %%
print(df.shape)
# Out:
# (891, 12)

# %% [markdown]
# ## wyświetlanie 3 ostatnie wiersze

# %%
print(df[-3:])
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %% [markdown]
# ## wyswietl 3 losowe wiersze

# %%
print(df.iloc[[20, 60, 80]])
# Out:
#     PassengerId  Survived  Pclass                   Name   Sex   Age  SibSp  \
# 20           21         0       2   Fynney, Mr. Joseph J  male  35.0      0
# 60           61         0       3  Sirayanian, Mr. Orsen  male  22.0      0
# 80           81         0       3   Waelens, Mr. Achille  male  22.0      0
#
#     Parch  Ticket     Fare Cabin Embarked Country  New_age
# 20      0  239865  26.0000   NaN        S      US     37.0
# 60      0    2669   7.2292   NaN        C      US     24.0
# 80      0  345767   9.0000   NaN        S      US     24.0

# %% [markdown]
# ## wyświetl ogólne informacje o zbiorze

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# ## wyświetl statystyki opisowe

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# ## zakres indeksów

# %%
df.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %% [markdown]
# ## lista kolumn

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# ## wyświetl kolumnę 'Survived'

# %%
df["Survived"]
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %% [markdown]
# ## Wyświetl kolumny:  'Survived' i 'Pclass'

# %%
df[["Survived", "Pclass"]]
# Out:
#      Survived  Pclass
# 0           0       3
# 1           1       1
# 2           1       3
# 3           1       1
# 4           0       3
# ..        ...     ...
# 886         0       2
# 887         1       1
# 888         0       3
# 889         1       1
# 890         0       3
#
# [891 rows x 2 columns]

# %% [markdown]
# ## wyświetl wiersze o indeksach od 20 do 24 włacznie

# %%
df.iloc[20:25]
# Out:
#     PassengerId  Survived  Pclass                           Name     Sex  \
# 20           21         0       2           Fynney, Mr. Joseph J    male
# 21           22         1       2          Beesley, Mr. Lawrence    male
# 22           23         1       3    McGowan, Miss. Anna "Annie"  female
# 23           24         1       1   Sloper, Mr. William Thompson    male
# 24           25         0       3  Palsson, Miss. Torborg Danira  female
#
#      Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# 20  35.0      0      0  239865  26.0000   NaN        S
# 21  34.0      0      0  248698  13.0000   D56        S
# 22  15.0      0      0  330923   8.0292   NaN        Q
# 23  28.0      0      0  113788  35.5000    A6        S
# 24   8.0      3      1  349909  21.0750   NaN        S

# %% [markdown]
# ## wyświetl wszystkie kolumny dla wierszy o indeksach od 10 do 14 włacznie

# %%
df.iloc[10:15]
# Out:
#     PassengerId  Survived  Pclass                                  Name  \
# 10           11         1       3       Sandstrom, Miss. Marguerite Rut
# 11           12         1       1              Bonnell, Miss. Elizabeth
# 12           13         0       3        Saundercock, Mr. William Henry
# 13           14         0       3           Andersson, Mr. Anders Johan
# 14           15         0       3  Vestrom, Miss. Hulda Amanda Adolfina
#
#        Sex   Age  SibSp  Parch     Ticket     Fare Cabin Embarked
# 10  female   4.0      1      1    PP 9549  16.7000    G6        S
# 11  female  58.0      0      0     113783  26.5500  C103        S
# 12    male  20.0      0      0  A/5. 2151   8.0500   NaN        S
# 13    male  39.0      1      5     347082  31.2750   NaN        S
# 14  female  14.0      0      0     350406   7.8542   NaN        S

# %% [markdown]
# ## wyświetl wszystkie wiersze dla kolumny o indeksie 0

# %%
df.iloc[:, 0]
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 886    887
# 887    888
# 888    889
# 889    890
# 890    891
# Name: PassengerId, Length: 891, dtype: int64

# %% [markdown]
# ## wyświetl fragment DF dla wierszy o indeksach od 10 do 14 włacznie i kolumn o indeksach od 3 do 4 włącznie

# %%
df.iloc[10:15, 3:5]
# Out:
#                                     Name     Sex
# 10       Sandstrom, Miss. Marguerite Rut  female
# 11              Bonnell, Miss. Elizabeth  female
# 12        Saundercock, Mr. William Henry    male
# 13           Andersson, Mr. Anders Johan    male
# 14  Vestrom, Miss. Hulda Amanda Adolfina  female

# %% [markdown]
# ## wyświetl fragment DF dla wierszy o indeksach od 10 do 14 włacznie i kolumn o indeksach od 3 do końca

# %%
df.iloc[10:15, 3:]
# Out:
#                                     Name     Sex   Age  SibSp  Parch  \
# 10       Sandstrom, Miss. Marguerite Rut  female   4.0      1      1
# 11              Bonnell, Miss. Elizabeth  female  58.0      0      0
# 12        Saundercock, Mr. William Henry    male  20.0      0      0
# 13           Andersson, Mr. Anders Johan    male  39.0      1      5
# 14  Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0      0
#
#        Ticket     Fare Cabin Embarked
# 10    PP 9549  16.7000    G6        S
# 11     113783  26.5500  C103        S
# 12  A/5. 2151   8.0500   NaN        S
# 13     347082  31.2750   NaN        S
# 14     350406   7.8542   NaN        S

# %% [markdown]
# ## wyświetl dfragment DF dla wierszy o indeksach od poczatku do 10 włacznie i kolumn 'Name' i 'Sex

# %%
df.iloc[:11][["Name", "Sex"]]
# Out:
#                                                  Name     Sex
# 0                             Braund, Mr. Owen Harris    male
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                              Heikkinen, Miss. Laina  female
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                            Allen, Mr. William Henry    male
# 5                                    Moran, Mr. James    male
# 6                             McCarthy, Mr. Timothy J    male
# 7                      Palsson, Master. Gosta Leonard    male
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female
# 10                    Sandstrom, Miss. Marguerite Rut  female

# %% [markdown]
# ## Wyświetl tylko te wiersze, dla których wiek jest wiekszy od 20

# %%
df[df["Age"] > 20]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 884          885         0       3
# 885          886         0       3
# 886          887         0       2
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 884                             Sutehall, Mr. Henry Jr    male  25.0      0
# 885               Rice, Mrs. William (Margaret Norton)  female  39.0      0
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 884      0   SOTON/OQ 392076   7.0500   NaN        S
# 885      5            382652  29.1250   NaN        Q
# 886      0            211536  13.0000   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [535 rows x 12 columns]

# %% [markdown]
# ## Wyświetl tylko tych pasażerów, których wiek jest niższy niż 20 lat i podrużowali w 1 klasie

# %%
df[np.logical_and(df["Age"] < 20, df["Pclass"] == 1)]
# Out:
#      PassengerId  Survived  Pclass  \
# 27            28         0       1
# 136          137         1       1
# 291          292         1       1
# 297          298         0       1
# 305          306         1       1
# 307          308         1       1
# 311          312         1       1
# 329          330         1       1
# 435          436         1       1
# 445          446         1       1
# 504          505         1       1
# 505          506         0       1
# 550          551         1       1
# 585          586         1       1
# 689          690         1       1
# 700          701         1       1
# 748          749         0       1
# 781          782         1       1
# 802          803         1       1
# 853          854         1       1
# 887          888         1       1
#
#                                                   Name     Sex    Age  SibSp  \
# 27                      Fortune, Mr. Charles Alexander    male  19.00      3
# 136                       Newsom, Miss. Helen Monypeny  female  19.00      0
# 291            Bishop, Mrs. Dickinson H (Helen Walton)  female  19.00      1
# 297                       Allison, Miss. Helen Loraine  female   2.00      1
# 305                     Allison, Master. Hudson Trevor    male   0.92      1
# 307  Penasco y Castellana, Mrs. Victor de Satode (M...  female  17.00      1
# 311                         Ryerson, Miss. Emily Borie  female  18.00      2
# 329                       Hippach, Miss. Jean Gertrude  female  16.00      0
# 435                          Carter, Miss. Lucile Polk  female  14.00      1
# 445                          Dodge, Master. Washington    male   4.00      0
# 504                              Maioni, Miss. Roberta  female  16.00      0
# 505         Penasco y Castellana, Mr. Victor de Satode    male  18.00      1
# 550                        Thayer, Mr. John Borland Jr    male  17.00      0
# 585                                Taussig, Miss. Ruth  female  18.00      0
# 689                  Madill, Miss. Georgette Alexandra  female  15.00      0
# 700  Astor, Mrs. John Jacob (Madeleine Talmadge Force)  female  18.00      1
# 748                          Marvin, Mr. Daniel Warner    male  19.00      1
# 781          Dick, Mrs. Albert Adrian (Vera Gillespie)  female  17.00      1
# 802                Carter, Master. William Thornton II    male  11.00      1
# 853                          Lines, Miss. Mary Conover  female  16.00      0
# 887                       Graham, Miss. Margaret Edith  female  19.00      0
#
#      Parch    Ticket      Fare            Cabin Embarked
# 27       2     19950  263.0000      C23 C25 C27        S
# 136      2     11752   26.2833              D47        S
# 291      0     11967   91.0792              B49        C
# 297      2    113781  151.5500          C22 C26        S
# 305      2    113781  151.5500          C22 C26        S
# 307      0  PC 17758  108.9000              C65        C
# 311      2  PC 17608  262.3750  B57 B59 B63 B66        C
# 329      1    111361   57.9792              B18        C
# 435      2    113760  120.0000          B96 B98        S
# 445      2     33638   81.8583              A34        S
# 504      0    110152   86.5000              B79        S
# 505      0  PC 17758  108.9000              C65        C
# 550      2     17421  110.8833              C70        C
# 585      2    110413   79.6500              E68        S
# 689      1     24160  211.3375               B5        S
# 700      0  PC 17757  227.5250          C62 C64        C
# 748      0    113773   53.1000              D30        S
# 781      0     17474   57.0000              B20        S
# 802      2    113760  120.0000          B96 B98        S
# 853      1  PC 17592   39.4000              D28        S
# 887      0    112053   30.0000              B42        S

# %% [markdown]
# ## Podostuj DF od najmniejszej do największej wartości na podstaiwe kolumny 'Cabin'

# %%
df.sort_values("Cabin", ascending=False)
# Out:
#      PassengerId  Survived  Pclass  \
# 339          340         0       1
# 394          395         1       3
# 205          206         0       3
# 251          252         0       3
# 10            11         1       3
# ..           ...       ...     ...
# 884          885         0       3
# 885          886         0       3
# 886          887         0       2
# 888          889         0       3
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 339                       Blackwell, Mr. Stephen Weart    male  45.0      0
# 394  Sandstrom, Mrs. Hjalmar (Agnes Charlotta Bengt...  female  24.0      0
# 205                         Strom, Miss. Telma Matilda  female   2.0      0
# 251         Strom, Mrs. Wilhelm (Elna Matilda Persson)  female  29.0      1
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# ..                                                 ...     ...   ...    ...
# 884                             Sutehall, Mr. Henry Jr    male  25.0      0
# 885               Rice, Mrs. William (Margaret Norton)  female  39.0      0
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch           Ticket     Fare Cabin Embarked
# 339      0           113784  35.5000     T        S
# 394      2          PP 9549  16.7000    G6        S
# 205      1           347054  10.4625    G6        S
# 251      1           347054  10.4625    G6        S
# 10       1          PP 9549  16.7000    G6        S
# ..     ...              ...      ...   ...      ...
# 884      0  SOTON/OQ 392076   7.0500   NaN        S
# 885      5           382652  29.1250   NaN        Q
# 886      0           211536  13.0000   NaN        S
# 888      2       W./C. 6607  23.4500   NaN        S
# 890      0           370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %% [markdown]
# ## Podostuj DF od najmniejszej do największej wartości na podstaiwe kolumny 'Age' i wyświetl 20 pierwszych wierszy

# %%
df.sort_values(by="Age", ascending=False).head(20)
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 630          631         1       1       Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                        Svensson, Mr. Johan
# 493          494         0       1                    Artagaveytia, Mr. Ramon
# 96            97         0       1                  Goldschmidt, Mr. George B
# 116          117         0       3                       Connors, Mr. Patrick
# 745          746         0       1               Crosby, Capt. Edward Gifford
# 672          673         0       2                Mitchell, Mr. Henry Michael
# 33            34         0       2                      Wheadon, Mr. Edward H
# 456          457         0       1                  Millet, Mr. Francis Davis
# 54            55         0       1             Ostby, Mr. Engelhart Cornelius
# 280          281         0       3                           Duane, Mr. Frank
# 438          439         0       1                          Fortune, Mr. Mark
# 545          546         0       1               Nicholson, Mr. Arthur Ernest
# 483          484         1       3                     Turkula, Mrs. (Hedwig)
# 275          276         1       1          Andrews, Miss. Kornelia Theodosia
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
# 252          253         0       1                  Stead, Mr. William Thomas
# 555          556         0       1                         Wright, Mr. George
# 570          571         1       2                         Harris, Mr. George
# 170          171         0       1                  Van der hoef, Mr. Wyckoff
#
#         Sex   Age  SibSp  Parch       Ticket      Fare        Cabin Embarked
# 630    male  80.0      0      0        27042   30.0000          A23        S
# 851    male  74.0      0      0       347060    7.7750          NaN        S
# 493    male  71.0      0      0     PC 17609   49.5042          NaN        C
# 96     male  71.0      0      0     PC 17754   34.6542           A5        C
# 116    male  70.5      0      0       370369    7.7500          NaN        Q
# 745    male  70.0      1      1    WE/P 5735   71.0000          B22        S
# 672    male  70.0      0      0   C.A. 24580   10.5000          NaN        S
# 33     male  66.0      0      0   C.A. 24579   10.5000          NaN        S
# 456    male  65.0      0      0        13509   26.5500          E38        S
# 54     male  65.0      0      1       113509   61.9792          B30        C
# 280    male  65.0      0      0       336439    7.7500          NaN        Q
# 438    male  64.0      1      4        19950  263.0000  C23 C25 C27        S
# 545    male  64.0      0      0          693   26.0000          NaN        S
# 483  female  63.0      0      0         4134    9.5875          NaN        S
# 275  female  63.0      1      0        13502   77.9583           D7        S
# 829  female  62.0      0      0       113572   80.0000          B28      NaN
# 252    male  62.0      0      0       113514   26.5500          C87        S
# 555    male  62.0      0      0       113807   26.5500          NaN        S
# 570    male  62.0      0      0  S.W./PP 752   10.5000          NaN        S
# 170    male  61.0      0      0       111240   33.5000          B19        S

# %% [markdown]
# ##Posortuj od największej do najmniejszej wartości na podstaiwe kolumny 'Fare'

# %%
df.sort_values(by="Fare", ascending=False)
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 258          259         1       1                    Ward, Miss. Anna
# 737          738         1       1              Lesurer, Mr. Gustave J
# 88            89         1       1          Fortune, Miss. Mabel Helen
# 438          439         0       1                   Fortune, Mr. Mark
# ..           ...       ...     ...                                 ...
# 806          807         0       1              Andrews, Mr. Thomas Jr
# 815          816         0       1                    Fry, Mr. Richard
# 466          467         0       2               Campbell, Mr. William
# 481          482         0       2    Frost, Mr. Anthony Wood "Archie"
# 822          823         0       1     Reuchlin, Jonkheer. John George
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C
# 88   female  23.0      3      2     19950  263.0000  C23 C25 C27        S
# 438    male  64.0      1      4     19950  263.0000  C23 C25 C27        S
# ..      ...   ...    ...    ...       ...       ...          ...      ...
# 806    male  39.0      0      0    112050    0.0000          A36        S
# 815    male   NaN      0      0    112058    0.0000         B102        S
# 466    male   NaN      0      0    239853    0.0000          NaN        S
# 481    male   NaN      0      0    239854    0.0000          NaN        S
# 822    male  38.0      0      0     19972    0.0000          NaN        S
#
# [891 rows x 12 columns]

# %% [markdown]
# # - Utwórz mową kolumny 'Country' i uzupełnij ją 'US'
# # - Wyświetl 5 pierwszych wierszy

# %%
df["Country"] = "US"

# %%
df["Country"].head()
# Out:
# 0    US
# 1    US
# 2    US
# 3    US
# 4    US
# Name: Country, dtype: object

# %% [markdown]
# ## Wyświetl kształt zbioru

# %%
df.shape
# Out:
# (891, 13)

# %% [markdown]
# ## zlicz liczbę wystąpień w poszczególnych kategoriach dla zmiennej 'Survived'

# %%
df.Survived.value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %% [markdown]
# ## zlicz libę kobiet i mężczyzn

# %%
df.Sex.value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %% [markdown]
# ## zlicz liczbę nienulowych wartości dla zmiennej 'Age'

# %%
df[~df.isnull()]["Age"].value_counts()
# Out:
# Age
# 24.00    30
# 22.00    27
# 18.00    26
# 28.00    25
# 30.00    25
#          ..
# 24.50     1
# 0.67      1
# 0.42      1
# 34.50     1
# 74.00     1
# Name: count, Length: 88, dtype: int64

# %% [markdown]
# ## minimalna wartość dla zmiennej wiek

# %%
df["Age"].min()
# Out:
# 0.42

# %% [markdown]
# ## średnia dla zmiennej wiek

# %%
df["Age"].mean()
# Out:
# np.float64(29.69911764705882)

# %% [markdown]
# ## maksymalna wartość dla zmiennej wiek

# %%
df["Age"].max()
# Out:
# 80.0

# %% [markdown]
# ## - Dodaj nową kolumnę 'New_age', w której do wieku będzie dodawane 2
# # - Wyświetl 3 pierwsze wiersze

# %%
df["New_age"] = df["Age"] + 2

df["New_age"].head(3)
# Out:
# 0    24.0
# 1    40.0
# 2    28.0
# Name: New_age, dtype: float64

# %% [markdown]
# ## zgrupuj dane według wartości w kolumnie 'Pclass' (klasa biletu) i obliczy średnią wartość wieku ('Age') w każdej z tych grup.

# %%
df.groupby("Pclass")["Age"].mean()
# Out:
# Pclass
# 1    38.233441
# 2    29.877630
# 3    25.140620
# Name: Age, dtype: float64

# %% [markdown]
# ## podaj jaka była średnia wieku dla kobiet i mężczyzn w grupie osób, które przeżyły i nie przezyły

# %%
df.groupby(["Survived", "Pclass"])["Age"].mean()
# Out:
# Survived  Pclass
# 0         1         43.695312
#           2         33.544444
#           3         26.555556
# 1         1         35.368197
#           2         25.901566
#           3         20.646118
# Name: Age, dtype: float64

# %% [markdown]
# ## Ile było osbób, które przezyły w grupie kobiet i mężczyzn

# %%
df.Sex.value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
df[df["Survived"] == 1].Sex.value_counts()
# Out:
# Sex
# female    233
# male      109
# Name: count, dtype: int64

# %% [markdown]
# ## - Usuń kolumnę 'Country'
# # - Wyswietl 4 pierwsze wiersze

# %%
df.drop(columns=["Country"], inplace=False).head(4)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
#
#    Parch            Ticket     Fare Cabin Embarked  New_age
# 0      0         A/5 21171   7.2500   NaN        S     24.0
# 1      0          PC 17599  71.2833   C85        C     40.0
# 2      0  STON/O2. 3101282   7.9250   NaN        S     28.0
# 3      0            113803  53.1000  C123        S     37.0

# %% [markdown]
# ## wyświetl kształt zbioru

# %%
df.shape
# Out:
# (891, 14)

# %% [markdown]
# ## - utwórz obiekt titanic_new1, do którego zapiszesz zbiór bez braków
# # - wyświetl 5 pierwszych wierszy - zwróć uwagę na indeksy

# %%
titanic_new1 = df.dropna()

titanic_new1.head(5)
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 6             7         0       1
# 10           11         1       3
# 11           12         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
#
#     Parch    Ticket     Fare Cabin Embarked Country  New_age
# 1       0  PC 17599  71.2833   C85        C      US     40.0
# 3       0    113803  53.1000  C123        S      US     37.0
# 6       0     17463  51.8625   E46        S      US     56.0
# 10      1   PP 9549  16.7000    G6        S      US      6.0
# 11      0    113783  26.5500  C103        S      US     60.0

# %% [markdown]
# ## - w zbiorze titanic_new1 zresetuj indeksy
# # - wyświetl 3 pierwsze wiersze

# %%
titanic_new1.reset_index().head(3)
# Out:
#    index  PassengerId  Survived  Pclass  \
# 0      1            2         1       1
# 1      3            4         1       1
# 2      6            7         0       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 2                            McCarthy, Mr. Timothy J    male  54.0      0
#
#    Parch    Ticket     Fare Cabin Embarked Country  New_age
# 0      0  PC 17599  71.2833   C85        C      US     40.0
# 1      0    113803  53.1000  C123        S      US     37.0
# 2      0     17463  51.8625   E46        S      US     56.0

# %% [markdown]
# ## wyświetl kształt nowego zbioru i porównaj go z poprzednim wynikiem

# %%
df.shape == titanic_new1.shape
# Out:
# False

# %%
# Out:
# (183, 13)

# %% [markdown]
# ## Wyświetl 10 pierwszych wierszy ramki danych titanic

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked Country  New_age
# 0      0         A/5 21171   7.2500   NaN        S      US     24.0
# 1      0          PC 17599  71.2833   C85        C      US     40.0
# 2      0  STON/O2. 3101282   7.9250   NaN        S      US     28.0
# 3      0            113803  53.1000  C123        S      US     37.0
# 4      0            373450   8.0500   NaN        S      US     37.0
# 5      0            330877   8.4583   NaN        Q      US      NaN
# 6      0             17463  51.8625   E46        S      US     56.0
# 7      1            349909  21.0750   NaN        S      US      4.0
# 8      2            347742  11.1333   NaN        S      US     29.0
# 9      0            237736  30.0708   NaN        C      US     16.0

# %% [markdown]
# ## w orginalnym obiekcie (titanic) uzupełnij brakujące wartosci dla zmiennej 'Age' wartością średnią
# ## Wyswietl 10 pierwszych wierszy

# %%
df["Age"].fillna(df["Age"].mean()).head(10)
# Out:
# 0    22.000000
# 1    38.000000
# 2    26.000000
# 3    35.000000
# 4    35.000000
# 5    29.699118
# 6    54.000000
# 7     2.000000
# 8    27.000000
# 9    14.000000
# Name: Age, dtype: float64

# %% [markdown]
# ## w zmiennej 'Cabine' braki danych uzupełnij napisem 'unknown'
# ## wyświetl 3 pierwsze wiersze

# %%
df["Cabin"].fillna("Unknown").head(3)
# Out:
# 0    Unknown
# 1        C85
# 2    Unknown
# Name: Cabin, dtype: object

# %% [markdown]
# # Dodaj nową kolumnę 'Age_cat', w której pojawią dwie kategorie:
# # - young dla osób poniżej 35 lat
# # - old dla pozostałych
#
# # wyswietl 5 pierwszych wierszy

# %%
df["Age_cat"] = df["Age"].apply(lambda x: "young" if x < 35 else "old")
df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare    Cabin Embarked  New_age Age_cat
# 0      0         A/5 21171   7.2500  unknown        S     24.0   young
# 1      0          PC 17599  71.2833      C85        C     40.0     old
# 2      0  STON/O2. 3101282   7.9250  unknown        S     28.0   young
# 3      0            113803  53.1000     C123        S     37.0     old
# 4      0            373450   8.0500  unknown        S     37.0     old

# %% [markdown]
# 👍
